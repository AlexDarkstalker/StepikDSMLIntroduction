# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
iris_data = pd.read_csv('iris/train_iris.csv')

# %%
iris_data
# Out:
#     Unnamed: 0  sepal length  sepal width  petal length  petal width  species
# 0          130           7.4          2.8           6.1          1.9        2
# 1            7           5.0          3.4           1.5          0.2        0
# 2           11           4.8          3.4           1.6          0.2        0
# 3          142           5.8          2.7           5.1          1.9        2
# 4          109           7.2          3.6           6.1          2.5        2
# ..         ...           ...          ...           ...          ...      ...
# 95         147           6.5          3.0           5.2          2.0        2
# 96         124           6.7          3.3           5.7          2.1        2
# 97         123           6.3          2.7           4.9          1.8        2
# 98         146           6.3          2.5           5.0          1.9        2
# 99          68           6.2          2.2           4.5          1.5        1
#
# [100 rows x 6 columns]

# %%
iris_data.shape
# Out:
# (100, 6)

# %%
iris_data.isnull().sum()
# Out:
# Unnamed: 0      0
# sepal length    0
# sepal width     0
# petal length    0
# petal width     0
# species         0
# dtype: int64

# %%
iris_data_test = pd.read_csv('iris/test_iris.csv')
iris_data_test
# Out:
#     Unnamed: 0  sepal length  sepal width  petal length  petal width  species
# 0          114           5.8          2.8           5.1          2.4        2
# 1           70           5.9          3.2           4.8          1.8        1
# 2          138           6.0          3.0           4.8          1.8        2
# 3           59           5.2          2.7           3.9          1.4        1
# 4           44           5.1          3.8           1.9          0.4        0
# 5          125           7.2          3.2           6.0          1.8        2
# 6           36           5.5          3.5           1.3          0.2        0
# 7          141           6.9          3.1           5.1          2.3        2
# 8           12           4.8          3.0           1.4          0.1        0
# 9           63           6.1          2.9           4.7          1.4        1
# 10         106           4.9          2.5           4.5          1.7        2
# ...

# %%
iris_data_test.shape
# Out:
# (50, 6)

# %%
X = iris_data.drop(['species'], axis=1)
X
# Out:
#     Unnamed: 0  sepal length  sepal width  petal length  petal width
# 0          130           7.4          2.8           6.1          1.9
# 1            7           5.0          3.4           1.5          0.2
# 2           11           4.8          3.4           1.6          0.2
# 3          142           5.8          2.7           5.1          1.9
# 4          109           7.2          3.6           6.1          2.5
# ..         ...           ...          ...           ...          ...
# 95         147           6.5          3.0           5.2          2.0
# 96         124           6.7          3.3           5.7          2.1
# 97         123           6.3          2.7           4.9          1.8
# 98         146           6.3          2.5           5.0          1.9
# 99          68           6.2          2.2           4.5          1.5
#
# [100 rows x 5 columns]

# %%
y = iris_data['species']
y
# Out:
# 0     2
# 1     0
# 2     0
# 3     2
# 4     2
#      ..
# 95    2
# 96    2
# 97    2
# 98    2
# 99    1
# Name: species, Length: 100, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
X_train, y_train = X, y

# %%
X_test, y_test = iris_data_test.drop(['species'], axis=1), iris_data_test['species']

# %%
from sklearn import tree

# %%
clf = tree.DecisionTreeClassifier(criterion='entropy', max_depth=2, random_state=0)
clf.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=2, random_state=0)

# %%
clf.score(X_train, y_train)
# Out:
# 1.0

# %%
clf.score(X_test, y_test)
# Out:
# 0.9696969696969697

# %%
max_depth_range = range(1, 100)

# %%
from sklearn.metrics import accuracy_score
from sklearn.model_selection import cross_val_score

# %%
np.random.seed(0)

# %%
iris_scores = pd.DataFrame(columns=['max_depth', 'train_score', 'test_score'])
for max_depth in max_depth_range:
    clf = tree.DecisionTreeClassifier(criterion='entropy', max_depth=max_depth)
    clf.fit(X_train, y_train)
    train_score = clf.score(X_train, y_train)
    y_pred = clf.predict(X_test)
    test_score = accuracy_score(y_true=y_test, y_pred=y_pred)
    cv_score = cross_val_score(clf, X_train, y_train, cv=5).mean()
#     test_score = clf.predict(X_test, y_test)
#     test_score = clf.score(X_test, y_test)
    tmp_score = pd.DataFrame({
        'max_depth': [max_depth],
        'train_score': [train_score],
        'test_score': [test_score],
        'mean_cv_score': [cv_score]
                })
    iris_scores = iris_scores.append(tmp_score)
iris_scores
# Out:
#    max_depth  train_score  test_score  mean_cv_score
# 0          1     0.716418    0.666667       0.716484
# 0          2     1.000000    0.969697       1.000000
# 0          3     1.000000    0.909091       1.000000
# 0          4     1.000000    0.909091       1.000000
# 0          5     1.000000    0.909091       1.000000
# ..       ...          ...         ...            ...
# 0         95     1.000000    0.909091       1.000000
# 0         96     1.000000    0.969697       0.985714
# 0         97     1.000000    0.909091       1.000000
# 0         98     1.000000    0.909091       1.000000
# 0         99     1.000000    0.909091       1.000000
#
# [99 rows x 4 columns]

# %%
iris_scores_long = iris_scores.melt(id_vars=['max_depth'], value_vars=['train_score', 'test_score', 'mean_cv_score'],
                                   var_name='set_type', value_name='scores')

# %%
iris_scores_long
# Out:
#     max_depth       set_type    scores
# 0           1    train_score  0.716418
# 1           2    train_score  1.000000
# 2           3    train_score  1.000000
# 3           4    train_score  1.000000
# 4           5    train_score  1.000000
# ..        ...            ...       ...
# 292        95  mean_cv_score  1.000000
# 293        96  mean_cv_score  0.985714
# 294        97  mean_cv_score  1.000000
# 295        98  mean_cv_score  1.000000
# 296        99  mean_cv_score  1.000000
#
# [297 rows x 3 columns]

# %%
sns.lineplot(data=iris_scores_long, x='max_depth', y='scores', hue='set_type')
# Out:
# <AxesSubplot:xlabel='max_depth', ylabel='scores'>
