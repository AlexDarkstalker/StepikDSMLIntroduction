# %%
import pandas as pd
import numpy as np

# %%
mush_data = pd.read_csv('training_mush.csv')
mush_data
# Out:
#       cap-shape  cap-surface  cap-color  bruises  odor  gill-attachment  \
# 0             2            0          3        1     5                1
# 1             2            0          4        0     5                1
# 2             2            0          3        0     2                1
# 3             0            0          3        0     5                1
# 4             2            3          3        1     5                1
# ...         ...          ...        ...      ...   ...              ...
# 6088          2            0          3        0     5                1
# 6089          3            2          2        0     2                1
# 6090          5            2          3        0     1                1
# 6091          3            2          3        0     5                1
# 6092          2            0          9        0     2                1
#
#       gill-spacing  gill-size  gill-color  stalk-shape  ...  \
# ...

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV

# %%
rf = RandomForestClassifier(random_state=0)

# %%
params = {"n_estimators": range(10, 51, 10), "max_depth": range(1, 13, 2), \
          "min_samples_leaf": range(1, 8), "min_samples_split": range(2, 10, 2)}

# %%
search = GridSearchCV(rf, param_grid=params, cv=3, n_jobs=-1)

# %%
X = mush_data.drop(["class"], axis=1)
X
# Out:
#       cap-shape  cap-surface  cap-color  bruises  odor  gill-attachment  \
# 0             2            0          3        1     5                1
# 1             2            0          4        0     5                1
# 2             2            0          3        0     2                1
# 3             0            0          3        0     5                1
# 4             2            3          3        1     5                1
# ...         ...          ...        ...      ...   ...              ...
# 6088          2            0          3        0     5                1
# 6089          3            2          2        0     2                1
# 6090          5            2          3        0     1                1
# 6091          3            2          3        0     5                1
# 6092          2            0          9        0     2                1
#
#       gill-spacing  gill-size  gill-color  stalk-shape  ...  \
# ...

# %%
y = mush_data['class']
y
# Out:
# 0       0
# 1       1
# 2       1
# 3       0
# 4       0
#        ..
# 6088    0
# 6089    1
# 6090    1
# 6091    0
# 6092    1
# Name: class, Length: 6093, dtype: int64

# %%
search.fit(X, y)
# Out:
# GridSearchCV(cv=3, estimator=RandomForestClassifier(random_state=0), n_jobs=-1,
#              param_grid={'max_depth': range(1, 13, 2),
#                          'min_samples_leaf': range(1, 8),
#                          'min_samples_split': range(2, 10, 2),
#                          'n_estimators': range(10, 51, 10)})

# %%
search.best_estimator_
# Out:
# RandomForestClassifier(max_depth=9, n_estimators=10, random_state=0)

# %%
search.best_params_
# Out:
# {'max_depth': 9,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'n_estimators': 10}

# %%
importance_data = pd.DataFrame(search.best_estimator_.feature_importances_, index=X.columns, columns=["importance"])
importance_data.sort_values(by="importance", ascending=False)
# Out:
#                           importance
# odor                        0.188376
# gill-color                  0.103861
# stalk-root                  0.103793
# spore-print-color           0.083564
# gill-spacing                0.080840
# ring-type                   0.070726
# bruises                     0.070109
# gill-size                   0.068461
# stalk-surface-below-ring    0.048296
# population                  0.043783
# stalk-surface-above-ring    0.031802
# habitat                     0.022611
# cap-color                   0.021773
# stalk-color-above-ring      0.017689
# ring-number                 0.013910
# veil-color                  0.010881
# stalk-shape                 0.007563
# stalk-color-below-ring      0.006253
# cap-surface                 0.003130
# cap-shape                   0.002577
# veil-type                   0.000000
# gill-attachment             0.000000

# %%
X_test = pd.read_csv("testing_mush.csv")
X_test
# Out:
#       cap-shape  cap-surface  cap-color  bruises  odor  gill-attachment  \
# 0             0            3          8        1     3                1
# 1             5            3          4        1     5                1
# 2             3            3          4        0     8                1
# 3             3            2          2        0     7                1
# 4             3            2          2        0     8                1
# ...         ...          ...        ...      ...   ...              ...
# 2026          3            3          2        0     2                1
# 2027          5            2          8        1     0                1
# 2028          5            3          3        0     2                1
# 2029          5            3          3        1     5                1
# 2030          5            3          3        0     2                1
#
#       gill-spacing  gill-size  gill-color  stalk-shape  ...  \
# ...

# %%
prediction = search.predict(X_test)
prediction
# Out:
# array([0, 0, 1, ..., 1, 0, 1], dtype=int64)

# %%
prediction.sum()
# Out:
# 976

# %%
from sklearn.metrics import confusion_matrix

# %%
y_true = pd.read_csv("testing_y_mush.csv")

# %%
y_true
# Out:
#       class
# 0         0
# 1         0
# 2         1
# 3         1
# 4         1
# ...     ...
# 2026      1
# 2027      0
# 2028      1
# 2029      0
# 2030      1
#
# [2031 rows x 1 columns]

# %%
confusion_matrix(y_true=y_true, y_pred=prediction)
# Out:
# array([[1055,    0],
#        [   0,  976]], dtype=int64)

# %%
import seaborn as sns

# %%
sns.heatmap(confusion_matrix(y_true=y_true, y_pred=prediction), annot=True, fmt='g')
# Out:
# <AxesSubplot:>
